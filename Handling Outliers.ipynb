# %% [markdown]
# 5 Number Summary ad BOXplot

# %%
## iminimun,maximum,q1,medaian ,q3
import numpy as np

# %%
marks=[45,32,56,75,89,54,32,89,85,96,7,4,12,75,5,36,78,25,68,25,14,45,89,90,91,92,63]
minimum,Q1,medain,Q3,maximim=np.quantile(marks,[0.0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,medain,Q3,maximim
# Out:
# (4.0, 28.5, 56.0, 87.0, 96.0)

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 58.5

# %%
lf=Q1-1.5*IQR
hf=Q3+1.5*IQR

# %%
lf
# Out:
# -59.25

# %%
hf
# Out:
# 174.75

# %%
marks=[45,32,56,75,89,54,32,89,85,96,7,4,12,75,5,36,78,25,68,25,14,45,89,90,91,92,63]

# %%
import seaborn as sns

# %%
sns.boxplot(marks)
# Out:
# <AxesSubplot: >

# %%
Smarks=[45,32,56,75,89,54,32,-250,-625,66,89,85,96,7,4,12,75,5,36,78,25,68,25,14,45,89,90,91,92,63]

# %%
sns.boxplot(Smarks)
# Out:
# <AxesSubplot: >
